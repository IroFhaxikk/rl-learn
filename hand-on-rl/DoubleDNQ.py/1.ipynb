# %%
import gymnasium as gym

# 打印所有已注册环境（包括 Atari）
for env_id in gym.registry.keys():
    if "ALE" in env_id:
        print(env_id)

# %%
import ale_py
print("ALE version:", ale_py.__version__)
# Out:
# ALE version: 0.11.2

# %% [markdown]
# #展示游戏的进程

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import time

env = gym.make("ALE/SpaceInvaders-v5", render_mode="rgb_array")
obs, info = env.reset()

for step in range(100):
    action = env.action_space.sample()
    obs, reward, done, truncated, info = env.step(action)
    
    plt.imshow(obs)
    plt.axis('off')
    plt.pause(0.02)
    plt.clf()
    
    if done or truncated:
        obs, info = env.reset()

env.close()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      12 plt.imshow(obs)
#      13 plt.axis('off')
# ---> 14 plt.pause(0.02)
#      15 plt.clf()
#      17 if done or truncated:
#
# File e:\Anaconda\envs\rl-learn\lib\site-packages\matplotlib\pyplot.py:757, in pause(interval)
#     755         canvas.draw_idle()
#     756     show(block=False)
# --> 757     canvas.start_event_loop(interval)
#     758 else:
#     759     time.sleep(interval)
#
# File e:\Anaconda\envs\rl-learn\lib\site-packages\matplotlib\backend_bases.py:2367, in FigureCanvasBase.start_event_loop(self, timeout)
#    2365 while self._looping and counter * timestep < timeout:
#    2366     self.flush_events()
# -> 2367     time.sleep(timestep)
#    2368     counter += 1
#
# KeyboardInterrupt:

# %%
print(env.action_space.n)
print(env.observation_space)
# Out:
# 6
# Box(0, 255, (210, 160, 3), uint8)
